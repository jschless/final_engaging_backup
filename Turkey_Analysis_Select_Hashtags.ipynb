# %%
import os 
from datetime import timedelta

import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

DATA_DIR = '/pool001/jschless/kiran-data/kiran-data/'
TURKEY_DIR = '/pool001/jschless/turkish_astroturfing'

# %%
# Loading df created in the Turkey_Data_Wrangling notebook
df = pd.read_pickle(os.path.join(DATA_DIR, 'mega_df_full_follower.pkl'))

# %%
# get all users that posted a lexicon tweet
astrobots = set(df.query('lexicon == True').author_id.unique())

# %%
len(df.trend.unique())
# Out:
# 418

# %% [markdown]
# ## Transforming Raw Data into A Panel of Time Series

# %%
def build_df(df, trend,
             include_missing=False, 
             drop_astrobots=True,
             time_bin='5Min', 
             minutes_to_round=5):
    # takes the dataframe and a hashtag and converts it to a event study dataframe for that hashtag

    df = df[df.trend == trend].set_index('created_at')
        
    if not include_missing: 
        # Remove tweets from users lacking follower info
        # df = df.query('author_id != -1 and author != "missing"')
        df = df[df.follower_data == True]

    if drop_astrobots:
        # Remove tweets from users that posted lexicon tweets
        df = df[~df.author_id.isin(astrobots)]

    try:
        start, end = df.iloc[0].tr_start, df.iloc[0].tr_end
    except Exception as e:
        print('issue with trending data for ', trend)
        return None
    start = start - timedelta(minutes=start.minute % minutes_to_round,
                              seconds=start.second,
                              microseconds=start.microsecond)

    df['tweet_type'] = df.text.apply(lambda x: 'retweet' if x.startswith('RT') else 'tweet')
    
    # Binning various statistics of interest
    series_list = []
    
    
    types = ['tweet', 'retweet']    
    # bin tweets and retweets separately
    for t in types:
        series_list.append(
            df[df.tweet_type == t]
              .resample(time_bin)
              .count()
              .author_id
        )
        
    # add in the tweets from unexposed users
    series_list.append(
        df.query('tweet_type == "tweet" and exposed == False')
          .resample(time_bin)
          .count()
          .author_id
    )
        
    new_df = pd.DataFrame(series_list).T
    new_df.columns = [*types, 'zero_exposure_tweets']
    
    # normalize time to minutes before / after trend
    new_df['absolute_time'] = new_df.index
    new_df.index = new_df.index - start
    new_df.index = new_df.index.map(lambda x: int(x.total_seconds() / 60))

    # add additional info to dataset
    new_df['trend'] = trend
    new_df['time'] = new_df.index
    new_df['time_i'] = range(len(new_df))
    new_df['trending_start'] = start

    return new_df

# %% [markdown]
# ### Selecting Specific Hashtags
# There are a lot of hashtags, so it might be worthwhile to remove the hashtags at either extreme.

# %%
sizes = df.groupby('trend').size()
lower, upper = .8, .975 # thresholds for which quantiles to include
l, u = sizes.quantile([lower, upper])

# only select trends between the lower and upper thresholds
trends = sizes.where(sizes <= u).where(sizes >= l).dropna().index

# %%
print(f'range of hashtags {l} - {u}')
print(f'# of hashtags: {len(trends)}')
# Out:
# range of hashtags 4797.200000000003 - 51541.34999999989
# # of hashtags: 73

# %%
sizes.where(sizes <= u).where(sizes >= l).dropna()
# Out:
# trend
# #2019ildısıiptalhakkı         34840.0
# #EskidenHerşeyÇokGüzeldi      26463.0
# #GümbürGümbürBinali           27483.0
# #HappyBirthdayTwitter         40044.0
# #SüresizSözleşmeliKadroya     37060.0
# #SüresizSözleşmeliyeAdalet    27592.0
# #YarınHerŞeyÇokGüzelOlacak    29691.0
# #YeniAskerlikSistemi          33938.0
# dtype: float64

# %% [markdown]
# ## Building Panel
# For each selected trend, build the panel

# %%
dfs = []
for trend in tqdm(trends):
    temp_df = build_df(df, trend, time_bin='5Min', minutes_to_round=5)

    if not temp_df is None:
        # assign dummy variable for whether a hashtag is trending or not
        temp_df = temp_df.assign(threshold=(temp_df.time > 0).astype(int))
        dfs.append(temp_df)
panel_df = pd.concat(dfs)
# Out:
# 100%|██████████| 73/73 [16:58<00:00, 13.95s/it]

# %%
panel_df.to_pickle(os.path.join(DATA_DIR, 'full_panel_all_followers_top_10_top_quartile.pkl'))

# %%
def plot_event_study(df, cat: str='zero_exposure_tweets', quantiles=(.025,.975),
                    lower=-120, upper=120, title=None):
    # useful for plotting panel data
    if title is None:
        title = cat
    df = df.loc[(df.index>lower)&(df.index<upper)]
    median = df.groupby('time')[cat].median()
    mean = df.groupby('time')[cat].mean()
    p025 = df.groupby('time')[cat].quantile(quantiles[0])
    p975 = df.groupby('time')[cat].quantile(quantiles[1])
    plt.errorbar(mean.index, mean, xerr=.5, yerr=[mean-p025, p975-mean],
                 fmt='o', capsize=10, label='mean')
    plt.scatter(median.index, median, c='r', label='median')
    print(df.describe())
    plt.title('Event Study of ' + title)
    plt.xlabel('Time Since Trending')
    plt.ylabel('Count')
    plt.legend()

# %%
plot_event_study(panel_df)
plt.axvline(c='grey', ls='--')
# Out:
#              tweet      retweet  zero_exposure_tweets         time  \
# count  2769.000000  1734.000000           2762.000000  2772.000000
# mean     39.664861     4.153403             11.048516    14.680736
# std      60.371678    11.047900             18.651336    65.556338
# min       0.000000     0.000000              0.000000  -115.000000
# 25%       0.000000     0.000000              0.000000   -35.000000
# 50%      13.000000     0.000000              3.000000    20.000000
# 75%      54.000000     4.000000             15.000000    70.000000
# max     496.000000   120.000000            156.000000   115.000000
#
#              time_i    threshold
# count  2.772000e+03  2772.000000
# mean   2.865485e+05     0.602092
# std    3.387063e+05     0.489555
# min    0.000000e+00     0.000000
# 25%    2.200000e+01     0.000000
# 50%    4.775250e+04     1.000000
# 75%    6.680172e+05     1.000000
# max    1.001213e+06     1.000000

# %% [markdown]
# ## Statistical Analysis

# %%
from statsmodels.formula.api import poisson
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.formula.api import negativebinomial

query = panel_df.query('time >= -60 & time <= 60').fillna(0)
query.trend = pd.Categorical(query.trend).codes
query = query.dropna()

formula_string = "tweet ~ time*threshold"

query['ln_tweet'] = np.log(query.tweet + 1)

ols = smf.ols(formula_string, data=query).fit(
    cov_type='cluster', cov_kwds={'groups': query['trend']})


re = smf.mixedlm(formula_string, data=query, groups=query['trend']).fit()
re_ln = smf.mixedlm('ln_' + formula_string, data=query, groups=query['trend']).fit()

#formula_string += "+ C(trend)"
pois = poisson(formula_string, data=query).fit()
negbin = negativebinomial(formula_string, data=query).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 29.028194
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 4.251597
#          Iterations: 20
#          Function evaluations: 25
#          Gradient evaluations: 25

# %%
from statsmodels.iolib.summary2 import summary_col
summary_col([re_ln, pois, negbin], 
           model_names=['Random Effects (logged outcome)', 'Poisson', 'Negative Binomial'],
           regressor_order=['time', 'threshold', 'time:threshold', 'Intercept'],
            drop_omitted=True)
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#
# =========================================================================
#                Random Effects (logged outcome) Poisson  Negative Binomial
# -------------------------------------------------------------------------
# time           0.0262                          0.0350   0.0329
#                (0.0019)                        (0.0006) (0.0032)
# threshold      1.3465                          0.6708   0.7201
#                (0.0896)                        (0.0171) (0.1601)
# time:threshold -0.0283                         -0.0359  -0.0339
#                (0.0025)                        (0.0007) (0.0045)
# Intercept      2.1941                          3.5000   3.4523
#                (0.1455)                        (0.0144) (0.1091)
# =========================================================================
# Standard errors in parentheses.
# """

# %%
np.exp(.6)
# Out:
# 1.8221188003905089

# %% [markdown]
# ## Who is tweeting before the hashtag trends?

# %%
len(df.drop_duplicates(subset=['id']).query('exposed == False and follower_data == True'))
# Out:
# 244069

# %%
before_trend = (df.drop_duplicates(subset=['id'])
                .query('exposed == False and follower_data == True')
                .query('time_since_trending < -5 and time_since_trending > -30')
               )
before_trend
# Out:
#                  created_at                   id  \
# 10974   2019-07-05 16:31:23  1147181188408401920
# 10994   2019-07-05 16:29:28  1147180704171810816
# 10996   2019-07-05 16:29:16  1147180654922260480
# 10998   2019-07-05 16:29:04  1147180605727236096
# 11005   2019-07-05 16:28:37  1147180493538037761
# ...                     ...                  ...
# 7988173 2019-06-18 18:05:21  1141044240333639686
# 7988174 2019-06-18 18:03:24  1141043750350835713
# 7988175 2019-06-18 18:03:24  1141043749868449793
# 7988176 2019-06-18 18:02:56  1141043632721584131
# 7988177 2019-06-18 18:02:27  1141043513271959558
#
#                                                       text           author  \
# 10974    @ekrem_imamoglu Başkanım mühendisler atama bek...       haritahane
# 10994    Kamuya 8bin bekçiyi rahatça alırken\n\nMühendi...        bseyldrkk
# 10996    İnşaat mühendislerine 12 ayda sadece 47 kadro ...        bseyldrkk
# 10998    Mülakatsız atama istiyoruz #ReisMühendisMimarA...        bseyldrkk
# 11005    Özel sektörde iş yok devlette yok. \nBiz ne ya...        bseyldrkk
# ...                                                    ...              ...
# 7988173             #HamzaHocaKomisyonuBitr yüzümüw gülsün    Faruk05377377
# 7988174  Müdürüm imzalar atılsın komisyon kurulsun #Ham...  Ramazan55932051
# 7988175          #HamzaHocaKomisyonuBitr\n1 İmza = 1 Hayat     Bubi81578575
# 7988176  Müdürüm komisyon kurulsun çok bekledik  #Hamza...  Ramazan55932051
# 7988177  Komisyonun kurulmasını bekliyoruz Hocam #Hamza...  Ramazan55932051
#
#                    author_id                    trend  exposed date  \
# 10974    1073513528647127040    #ReisMühendisMimarAta    False  NaT
# 10994              417426960    #ReisMühendisMimarAta    False  NaT
# 10996              417426960    #ReisMühendisMimarAta    False  NaT
# 10998              417426960    #ReisMühendisMimarAta    False  NaT
# 11005              417426960    #ReisMühendisMimarAta    False  NaT
# ...                      ...                      ...      ...  ...
# 7988173  1131554702322216960  #HamzaHocaKomisyonuBitr    False  NaT
# 7988174  1003742209890496518  #HamzaHocaKomisyonuBitr    False  NaT
# 7988175  1132777442916130817  #HamzaHocaKomisyonuBitr    False  NaT
# 7988176  1003742209890496518  #HamzaHocaKomisyonuBitr    False  NaT
# 7988177  1003742209890496518  #HamzaHocaKomisyonuBitr    False  NaT
#
#         trend_date tweet_type            tr_start              tr_end  vol  \
# 10974          NaT        NaN 2019-07-05 16:37:48 2019-07-05 18:07:49   -1
# 10994          NaT        NaN 2019-07-05 16:37:48 2019-07-05 18:07:49   -1
# 10996          NaT        NaN 2019-07-05 16:37:48 2019-07-05 18:07:49   -1
# 10998          NaT        NaN 2019-07-05 16:37:48 2019-07-05 18:07:49   -1
# 11005          NaT        NaN 2019-07-05 16:37:48 2019-07-05 18:07:49   -1
# ...            ...        ...                 ...                 ...  ...
# 7988173        NaT        NaN 2019-06-18 18:13:27 2019-06-18 19:19:50   -1
# 7988174        NaT        NaN 2019-06-18 18:13:27 2019-06-18 19:19:50   -1
# 7988175        NaT        NaN 2019-06-18 18:13:27 2019-06-18 19:19:50   -1
# 7988176        NaT        NaN 2019-06-18 18:13:27 2019-06-18 19:19:50   -1
# 7988177        NaT        NaN 2019-06-18 18:13:27 2019-06-18 19:19:50   -1
#
#          max_rank                   lifetime  attack time_trending  \
# 10974           3  0 days 01:30:01.000000000    True      01:30:01
# 10994           3  0 days 01:30:01.000000000    True      01:30:01
# 10996           3  0 days 01:30:01.000000000    True      01:30:01
# 10998           3  0 days 01:30:01.000000000    True      01:30:01
# 11005           3  0 days 01:30:01.000000000    True      01:30:01
# ...           ...                        ...     ...           ...
# 7988173         1  0 days 01:06:23.000000000    True      01:06:23
# 7988174         1  0 days 01:06:23.000000000    True      01:06:23
# 7988175         1  0 days 01:06:23.000000000    True      01:06:23
# 7988176         1  0 days 01:06:23.000000000    True      01:06:23
# 7988177         1  0 days 01:06:23.000000000    True      01:06:23
#
#          time_since_trending  lexicon  follower_data
# 10974                     -6    False           True
# 10994                     -8    False           True
# 10996                     -8    False           True
# 10998                     -8    False           True
# 11005                     -9    False           True
# ...                      ...      ...            ...
# 7988173                   -8    False           True
# 7988174                  -10    False           True
# 7988175                  -10    False           True
# 7988176                  -10    False           True
# 7988177                  -11    False           True
#
# [1443 rows x 20 columns]

# %%
query.zero_exposure_tweets.sum()
# Out:
# 46000.0

# %%
df['tweet_type'] = df.text.apply(lambda x: 'retweet' if x.startswith('RT') else 'tweet')
trimming_df = df
print('df starting size', len(trimming_df))
trimming_df = trimming_df.drop_duplicates(subset=['id'])
print('df after removing duplicated tweet ids', len(trimming_df))

trimming_df = trimming_df.query('tweet_type == "tweet"')
print('df after removing retweets', len(trimming_df))

trimming_df = trimming_df.query('follower_data == True')
print('df after removing tweets from users without following data', len(trimming_df))

astrobots = set(df.query('lexicon == True').author_id.unique())
trimming_df = trimming_df[~trimming_df.author_id.isin(astrobots)]
print('df after removing astrobot tweets', len(trimming_df))

trimming_df = trimming_df.query('exposed == False')
print('df after removing exposed tweets', len(trimming_df))

# trimming_df = trimming_df.query('time_since_trending <= 60 and time_since_trending >= -60')
# print('df after removing tweets from outside the hour before and after', len(trimming_df))
# Out:
# df starting size 17829530
# df after removing duplicated tweet ids 3051252
# df after removing retweets 2997521
# df after removing tweets from users without following data 2422731
# df after removing astrobot tweets 2052588
# df after removing exposed tweets 205439

# %%
trimming_df.describe()
# Out:
#                  id     author_id            vol      max_rank  \
# count  1.461000e+04  1.461000e+04   14610.000000  14610.000000
# mean   1.075116e+18  6.130679e+17   11180.313621      1.449624
# std    1.890861e+17  4.968351e+17   37362.347783      0.917182
# min    1.082295e+10  9.135112e+06      -1.000000      1.000000
# 25%    9.841624e+17  2.675648e+09      -1.000000      1.000000
# 50%    1.130085e+18  8.229652e+17      -1.000000      1.000000
# 75%    1.149419e+18  1.049335e+18      -1.000000      1.000000
# max    1.408818e+18  1.376274e+18  414069.000000      7.000000
#
#        time_since_trending
# count         1.461000e+04
# mean         -2.727689e+05
# std           7.559540e+05
# min          -4.883148e+06
# 25%          -6.241628e+05
# 50%          -5.765200e+04
# 75%           1.563500e+03
# max           1.060808e+06

# %%
trimming_df
# Out:
#                  created_at                   id  \
# 0       2020-05-02 14:05:16  1256585550796148738
# 84      2019-10-29 23:51:31  1189328944518049798
# 114     2019-10-28 18:27:40  1188885055361425408
# 117     2019-10-28 18:25:13  1188884438702264322
# 120     2019-10-28 18:20:43  1188883306093404161
# ...                     ...                  ...
# 7985965 2019-06-15 16:10:55  1139928280151158784
# 7985966 2019-06-15 16:03:31  1139926419528491008
# 7985974 2019-06-15 14:41:52  1139905870014238720
# 7986467 2019-07-10 16:54:56  1148999052861804544
# 7987417 2019-06-11 19:41:14  1138531655688343554
#
#                                                       text           author  \
# 0        #MilliGazeteOkuyorum #SesimizBir #Cumartesi #D...     GunesliGuzel
# 84       #AtatürkünSevdiğiYemekler En çokta zeytinyağlı...  alialemdaroglu_
# 114      #ÜniversiteliİşçilereAdalet tayin hakkınız olm...  Keremde93551456
# 117      #ÜniversiteliİşçilereAdalet bir kamu çalışanın...  Keremde93551456
# 120      #ÜniversiteliİşçilereAdalet Üniversite mezunu ...  Keremde93551456
# ...                                                    ...              ...
# 7985965  Check Out City of Girls https://t.co/OypMxLpdG...       AryanTramp
# 7985966  Check Out Where the crawdads sing https://t.co...       AryanTramp
# 7985974  Download any of your favorite music &amp; vide...     Aziz_NumbOne
# 7986467  #Tesladandogumgünühediyesi https://t.co/tZer70...       sosyoparti
# 7987417  Ayrıntılar ve  Satın Alma İçin = https://t.co/...  hediyekarakalem
#
#                    author_id                         trend  exposed date  \
# 0                  293656352   #ÜniversiteliİşçilereAdalet    False  NaT
# 84        872503566090547201   #ÜniversiteliİşçilereAdalet    False  NaT
# 114      1159443820033052673   #ÜniversiteliİşçilereAdalet    False  NaT
# 117      1159443820033052673   #ÜniversiteliİşçilereAdalet    False  NaT
# 120      1159443820033052673   #ÜniversiteliİşçilereAdalet    False  NaT
# ...                      ...                           ...      ...  ...
# 7985965            874934545  #celtabetterouletteturnuvasi    False  NaT
# 7985966            874934545  #celtabetterouletteturnuvasi    False  NaT
# 7985974            477416472  #celtabetterouletteturnuvasi    False  NaT
# 7986467  1143901319591280640    #Tesladandogumgünühediyesi    False  NaT
# 7987417  1065556066975563777           #betexper25FreeSpin    False  NaT
#
#         trend_date tweet_type            tr_start              tr_end  vol  \
# 0              NaT      tweet 2019-07-05 17:32:49 2019-07-05 18:12:53   -1
# 84             NaT      tweet 2019-07-05 17:32:49 2019-07-05 18:12:53   -1
# 114            NaT      tweet 2019-07-05 17:32:49 2019-07-05 18:12:53   -1
# 117            NaT      tweet 2019-07-05 17:32:49 2019-07-05 18:12:53   -1
# 120            NaT      tweet 2019-07-05 17:32:49 2019-07-05 18:12:53   -1
# ...            ...        ...                 ...                 ...  ...
# 7985965        NaT      tweet 2019-06-27 15:20:09 2019-06-27 16:34:48   -1
# 7985966        NaT      tweet 2019-06-27 15:20:09 2019-06-27 16:34:48   -1
# 7985974        NaT      tweet 2019-06-27 15:20:09 2019-06-27 16:34:48   -1
# 7986467        NaT      tweet 2019-07-10 15:32:00 2019-07-10 17:36:58   -1
# 7987417        NaT      tweet 2019-06-22 16:12:48 2019-06-22 18:22:45   -1
#
#          max_rank                   lifetime  attack  time_since_trending  \
# 0               1  0 days 00:40:04.000000000    True               434672
# 84              1  0 days 00:40:04.000000000    True               167418
# 114             1  0 days 00:40:04.000000000    True               165654
# 117             1  0 days 00:40:04.000000000    True               165652
# 120             1  0 days 00:40:04.000000000    True               165647
# ...           ...                        ...     ...                  ...
# 7985965         5  0 days 01:14:39.000000000    True               -17229
# 7985966         5  0 days 01:14:39.000000000    True               -17236
# 7985974         5  0 days 01:14:39.000000000    True               -17318
# 7986467         5  0 days 02:04:58.000000000    True                   82
# 7987417         2  0 days 02:09:57.000000000    True               -15631
#
#          lexicon  follower_data
# 0          False           True
# 84         False           True
# 114        False           True
# 117        False           True
# 120        False           True
# ...          ...            ...
# 7985965    False           True
# 7985966    False           True
# 7985974    False           True
# 7986467    False           True
# 7987417    False           True
#
# [14610 rows x 19 columns]

# %% [markdown]
# # Maybe the Trend Dates are Parsed Incorrectly?

# %%
TURKEY_DIR = '/pool001/jschless/turkish_astroturfing'

trend_file = 'trend_analysis_top10.csv' 
#trend_file = 'world_trend_analysis_top10.csv'

trending_info = pd.read_csv(os.path.join(TURKEY_DIR, trend_file),
                           parse_dates=['tr_start', 'tr_end', 'lifetime', 'date'])

trending_info['trend'] = trending_info.keyword

trending_info = trending_info.drop(columns=['date', 'id', 'keyword'])


trending_info.head()
# Out:
#              tr_start              tr_end     vol  max_rank  \
# 0 2019-06-27 06:14:01 2019-06-27 08:09:03      -1         8
# 1 2019-06-20 18:38:28 2019-06-20 22:24:33   14474         1
# 2 2019-06-20 22:29:29 2019-06-20 23:59:37   14495         6
# 3 2019-07-15 04:12:22 2019-07-15 13:02:52  118537         1
# 4 2019-07-15 13:32:57 2019-07-15 13:47:54  124473         1
#
#                     lifetime  attack                      trend
# 0  0 days 01:55:02.000000000   False                    "Maçka"
# 1  0 days 03:46:05.000000000    True  #1200ÜcretliAtamasıHaktır
# 2  0 days 01:30:08.000000000   False  #1200ücretliatamasıhaktır
# 3  0 days 08:50:30.000000000   False           #15TEMMUZDESTANI
# 4  0 days 00:14:57.000000000   False           #15TEMMUZDESTANI

# %%
trending_info2 = pd.read_csv(os.path.join(TURKEY_DIR, trend_file))
trending_info2.query('keyword == "#ÜniversiteliİşçilereAdalet"')
# Out:
#                                                    id             tr_start  \
# 1405  #ÜniversiteliİşçilereAdalet_2019-07-05_17:32:49  2019-07-05 17:32:49
# 1406  #ÜniversiteliİşçilereAdalet_2019-07-05_18:22:52  2019-07-05 18:22:52
# 1407  #ÜniversiteliİşçilereAdalet_2019-07-05_19:52:41  2019-07-05 19:52:41
#
#                    tr_end  vol  max_rank                   lifetime  \
# 1405  2019-07-05 18:12:53   -1         1  0 days 00:40:04.000000000
# 1406  2019-07-05 19:42:43   -1         4  0 days 01:19:51.000000000
# 1407  2019-07-05 20:57:40   -1         5  0 days 01:04:59.000000000
#
#                           keyword        date  attack
# 1405  #ÜniversiteliİşçilereAdalet  2019-07-05    True
# 1406  #ÜniversiteliİşçilereAdalet  2019-07-05    True
# 1407  #ÜniversiteliİşçilereAdalet  2019-07-05    True
